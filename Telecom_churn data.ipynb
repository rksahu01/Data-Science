# %% [markdown]
# <table>
# <tr>
# <td width=15%><img src="https://www.nitrkl.ac.in/assets/images/logo.png"></img></td>
# <td><center><h1>National Institute of Technology
# Rourkela, Odisha, India, 769008</h1><h2>Department of Computer Science Engineering</h2></center></td>
# </tr>
# <tr><td colspan=2><center><h3>Laborotary-2</h3></br>
#             <b>(Data Science Laborotary)</b></center></td></tr>
# </table>

# %%
import numpy as np #Numpy stands for Numerical Python. used for numerical Operations
import pandas as pd #Pandas is used for DataFrame/Database Operations
import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.precision", 2)

# %% [markdown]
# Read the telecom_churn csv file.

# %%
data=pd.read_csv('telecom_churn.csv')

# %% [markdown]
# Show the first 10 rows of the dataset

# %%
data.head(10)
# Out:
#   State  Account length  Area code International plan Voice mail plan  \
# 0    KS             128        415                 No             Yes
# 1    OH             107        415                 No             Yes
# 2    NJ             137        415                 No              No
# 3    OH              84        408                Yes              No
# 4    OK              75        415                Yes              No
# 5    AL             118        510                Yes              No
# 6    MA             121        510                 No             Yes
# 7    MO             147        415                Yes              No
# 8    LA             117        408                 No              No
# 9    WV             141        415                Yes             Yes
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                   25.0              265.1              110
# 1                   26.0              161.6              123
# 2                    NaN              243.4              114
# 3                    NaN              299.4               71
# 4                    0.0              166.7              113
# 5                    0.0                NaN               98
# 6                   24.0              218.2               88
# 7                    0.0              157.0               79
# 8                    0.0              184.5               97
# 9                   37.0              258.6               84
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
# 5             37.98              220.6              101             18.75
# 6             37.09              348.5              108             29.62
# 7             26.69              103.1               94              8.76
# 8             31.37              351.6               80             29.89
# 9             43.96              222.0              111             18.87
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
# 5                203.9                118                9.18
# 6                212.6                118                9.57
# 7                211.8                 96                9.53
# 8                215.8                 90                9.71
# 9                326.4                 97               14.69
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
# 5                 6.3                 6               1.70
# 6                 7.5                 7               2.03
# 7                 7.1                 6               1.92
# 8                 8.7                 4               2.35
# 9                11.2                 5               3.02
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False
# 5                       0  False
# 6                       3  False
# 7                       0  False
# 8                       1  False
# 9                       0  False

# %% [markdown]
# Show the last 10 rows of the dataset

# %%
data.tail(10)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 3323    IN             117        415                 No              No
# 3324    WV             159        415                 No              No
# 3325    OH              78        408                 No              No
# 3326    OH              96        415                 No              No
# 3327    SC              79        415                 No              No
# 3328    AZ             192        415                 No             Yes
# 3329    WV              68        415                 No              No
# 3330    RI              28        510                 No              No
# 3331    CT             184        510                Yes              No
# 3332    TN              74        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 3323                    0.0              118.4              126
# 3324                    0.0              169.8              114
# 3325                    0.0              193.4               99
# 3326                    0.0              106.6              128
# 3327                    0.0              134.7               98
# 3328                   36.0              156.2               77
# 3329                    0.0              231.1               57
# 3330                    0.0              180.8              109
# 3331                    0.0              213.8              105
# 3332                   25.0              234.4              113
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 3323             20.13              249.3               97             21.19
# 3324             28.87              197.7              105             16.80
# 3325             32.88              116.9               88              9.94
# 3326             18.12              284.8               87             24.21
# 3327             22.90              189.7               68             16.12
# 3328             26.55              215.5              126             18.32
# 3329             39.29              153.4               55             13.04
# 3330             30.74              288.8               58             24.55
# 3331             36.35              159.6               84             13.57
# 3332             39.85              265.9               82             22.60
#
#       Total night minutes  Total night calls  Total night charge  \
# 3323                227.0                 56               10.22
# 3324                193.7                 82                8.72
# 3325                243.3                109               10.95
# 3326                178.9                 92                8.05
# 3327                221.4                128                9.96
# 3328                279.1                 83               12.56
# 3329                191.3                123                8.61
# 3330                191.9                 91                8.64
# 3331                139.2                137                6.26
# 3332                241.4                 77               10.86
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 3323                13.6                 3               3.67
# 3324                11.6                 4               3.13
# 3325                 9.3                 4               2.51
# 3326                14.9                 7               4.02
# 3327                11.8                 5               3.19
# 3328                 9.9                 6               2.67
# 3329                 9.6                 4               2.59
# 3330                14.1                 6               3.81
# 3331                 5.0                10               1.35
# 3332                13.7                 4               3.70
#
#       Customer service calls  Churn
# 3323                       5   True
# 3324                       1  False
# 3325                       2  False
# 3326                       1  False
# 3327                       2  False
# 3328                       2  False
# 3329                       3  False
# 3330                       2  False
# 3331                       2  False
# 3332                       0  False

# %% [markdown]
# Show the dimensions (No. of rows and coulmns) of the dataset

# %%
data.shape
# Out:
# (3333, 20)

# %% [markdown]
# Print all the column names of the dataset

# %%
#Your answer here
data.columns
# Out:
# Index(['State', 'Account length', 'Area code', 'International plan',
#        'Voice mail plan', 'Number vmail messages', 'Total day minutes',
#        'Total day calls', 'Total day charge', 'Total eve minutes',
#        'Total eve calls', 'Total eve charge', 'Total night minutes',
#        'Total night calls', 'Total night charge', 'Total intl minutes',
#        'Total intl calls', 'Total intl charge', 'Customer service calls',
#        'Churn'],
#       dtype='object')

# %% [markdown]
# Print general information of the dataset like column, and datatype.

# %%
#Your answer here
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3333 entries, 0 to 3332
# Data columns (total 20 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   State                   3333 non-null   object
#  1   Account length          3333 non-null   int64
#  2   Area code               3333 non-null   int64
#  3   International plan      3333 non-null   object
#  4   Voice mail plan         3333 non-null   object
#  5   Number vmail messages   3328 non-null   float64
#  6   Total day minutes       3329 non-null   float64
#  7   Total day calls         3333 non-null   int64
#  8   Total day charge        3333 non-null   float64
#  9   Total eve minutes       3333 non-null   float64
#  10  Total eve calls         3333 non-null   int64
#  11  Total eve charge        3333 non-null   float64
#  12  Total night minutes     3333 non-null   float64
#  13  Total night calls       3333 non-null   int64
#  14  Total night charge      3333 non-null   float64
#  15  Total intl minutes      3333 non-null   float64
#  16  Total intl calls        3333 non-null   int64
#  17  Total intl charge       3333 non-null   float64
#  18  Customer service calls  3333 non-null   int64
#  19  Churn                   3333 non-null   bool
# dtypes: bool(1), float64(9), int64(7), object(3)
# memory usage: 498.1+ KB

# %% [markdown]
# After getting the datatype of every feature, you can see that there is a feature "**churn**" having Dtype as **bool**. Change that Dtype to **int64**.

# %%
#Your answer here
data['Churn']=data['Churn'].astype(int)

# %% [markdown]
# Which method shows basic statistical characteristics of each numerical feature (`int64` and `float64` types): number of non-missing values, mean, standard deviation, range, median, 0.25 and 0.75 quartiles.

# %%
#Your answer here
data.describe()
# Out:
#        Account length  Area code  Number vmail messages  Total day minutes  \
# count         3333.00    3333.00                3328.00            3329.00
# mean           101.06     437.18                   8.11             179.78
# std             39.82      42.37                  13.70              54.48
# min              1.00     408.00                   0.00               0.00
# 25%             74.00     408.00                   0.00             143.70
# 50%            101.00     415.00                   0.00             179.40
# 75%            127.00     510.00                  20.00             216.40
# max            243.00     510.00                  51.00             350.80
#
#        Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# count          3333.00           3333.00            3333.00          3333.00
# mean            100.44             30.56             200.98           100.11
# std              20.07              9.26              50.71            19.92
# min               0.00              0.00               0.00             0.00
# 25%              87.00             24.43             166.60            87.00
# 50%             101.00             30.50             201.40           100.00
# 75%             114.00             36.79             235.30           114.00
# max             165.00             59.64             363.70           170.00
#
#        Total eve charge  Total night minutes  Total night calls  \
# count           3333.00              3333.00            3333.00
# mean              17.08               200.87             100.11
# std                4.31                50.57              19.57
# min                0.00                23.20              33.00
# 25%               14.16               167.00              87.00
# 50%               17.12               201.20             100.00
# 75%               20.00               235.30             113.00
# max               30.91               395.00             175.00
#
#        Total night charge  Total intl minutes  Total intl calls  \
# count             3333.00             3333.00           3333.00
# mean                 9.04               10.24              4.48
# std                  2.28                2.79              2.46
# min                  1.04                0.00              0.00
# 25%                  7.52                8.50              3.00
# 50%                  9.05               10.30              4.00
# 75%                 10.59               12.10              6.00
# max                 17.77               20.00             20.00
#
#        Total intl charge  Customer service calls    Churn
# count            3333.00                 3333.00  3333.00
# mean                2.76                    1.56     0.14
# std                 0.75                    1.32     0.35
# min                 0.00                    0.00     0.00
# 25%                 2.30                    1.00     0.00
# 50%                 2.78                    1.00     0.00
# 75%                 3.27                    2.00     0.00
# max                 5.40                    9.00     1.00

# %% [markdown]
# Now show basic statistics on non-numerical features.

# %%
for i in data.columns:
    if data[i].dtype=='object':
        print(i,data[i].count())
        print(data[i].value_counts())
# Out:
# State 3333
# State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64
# International plan 3333
# International plan
# No     3010
# Yes     323
# Name: count, dtype: int64
# Voice mail plan 3333
# Voice mail plan
# No     2411
# Yes     922
# Name: count, dtype: int64

# %% [markdown]
# How to show the basic statistics for categorical (type `object`) and boolean (type `bool`) features?

# %%
#Your answer here
for i in data.columns:
    if data[i].dtype=='object' or data[i].dtype=='bool' :
        print(i,data[i].count())
        print(data[i].value_counts())
# Out:
# State 3333
# State
# WV    106
# MN     84
# NY     83
# AL     80
# WI     78
# OH     78
# OR     78
# WY     77
# VA     77
# CT     74
# MI     73
# ID     73
# VT     73
# TX     72
# UT     72
# IN     71
# MD     70
# KS     70
# NC     68
# NJ     68
# MT     68
# CO     66
# NV     66
# WA     66
# RI     65
# MA     65
# MS     65
# AZ     64
# FL     63
# MO     63
# NM     62
# ME     62
# ND     62
# NE     61
# OK     61
# DE     61
# SC     60
# SD     60
# KY     59
# IL     58
# NH     56
# AR     55
# GA     54
# DC     54
# HI     53
# TN     53
# AK     52
# LA     51
# PA     45
# IA     44
# CA     34
# Name: count, dtype: int64
# International plan 3333
# International plan
# No     3010
# Yes     323
# Name: count, dtype: int64
# Voice mail plan 3333
# Voice mail plan
# No     2411
# Yes     922
# Name: count, dtype: int64

# %% [markdown]
# <h2>Check for Missing Values</h2>
#
# How to check for missing values in each column?

# %%
#Your answer here
data.isnull().sum()
# Out:
# State                     0
# Account length            0
# Area code                 0
# International plan        0
# Voice mail plan           0
# Number vmail messages     5
# Total day minutes         4
# Total day calls           0
# Total day charge          0
# Total eve minutes         0
# Total eve calls           0
# Total eve charge          0
# Total night minutes       0
# Total night calls         0
# Total night charge        0
# Total intl minutes        0
# Total intl calls          0
# Total intl charge         0
# Customer service calls    0
# Churn                     0
# dtype: int64

# %% [markdown]
# <h2> Sorting</h2>
#
# How to sort a dataFrame using one of the variables (i.e columns) in ascending order and also in descending order?

# %%
#Your answer here
data.sort_values(by='Total day calls', ascending=False, inplace=True)
data.head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1121    MI              91        415                 No              No
# 468     AZ              86        415                 No             Yes
# 1460    MT              80        415                 No              No
# 2392    WY              90        510                 No              No
# 1057    WV              86        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1121                    0.0              154.4              165
# 468                    32.0               70.9              163
# 1460                    0.0              198.1              160
# 2392                    0.0              125.4              158
# 1057                   38.0              123.0              158
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1121             26.25              168.3              121             14.31
# 468              12.05              166.7              121             14.17
# 1460             33.68              156.7               87             13.32
# 2392             21.32              269.1               83             22.87
# 1057             20.91              133.9              119             11.38
#
#       Total night minutes  Total night calls  Total night charge  \
# 1121                239.9                 81               10.80
# 468                 244.9                105               11.02
# 1460                182.1                 76                8.19
# 2392                238.6                103               10.74
# 1057                138.2                103                6.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1121                11.7                 4               3.16
# 468                 11.1                 5               3.00
# 1460                 9.3                 3               2.51
# 2392                11.0                 7               2.97
# 1057                13.3                 4               3.59
#
#       Customer service calls  Churn
# 1121                       5      1
# 468                        3      0
# 1460                       3      0
# 2392                       1      0
# 1057                       1      0

# %%
data.sort_values(by='Total day calls', ascending=True, inplace=True)
data.head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1397    VT             101        510                 No              No
# 1345    SD              98        415                 No              No
# 1144    NH             155        408                 No              No
# 1989    MT             124        415                 No             Yes
# 692     NE              82        408                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1397                    0.0                0.0                0
# 1345                    0.0                0.0                0
# 1144                    0.0              216.7               30
# 1989                   30.0              144.5               35
# 692                     0.0              185.8               36
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1397              0.00              192.1              119             16.33
# 1345              0.00              159.6              130             13.57
# 1144             36.84              144.3              125             12.27
# 1989             24.57              262.3              101             22.30
# 692              31.59              276.5              134             23.50
#
#       Total night minutes  Total night calls  Total night charge  \
# 1397                168.8                 95                7.60
# 1345                167.1                 88                7.52
# 1144                135.3                106                6.09
# 1989                226.5                 82               10.19
# 692                 192.1                104                8.64
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1397                 7.2                 4               1.94
# 1345                 6.8                 1               1.84
# 1144                10.8                 1               2.92
# 1989                12.0                 7               3.24
# 692                  5.7                 7               1.54
#
#       Customer service calls  Churn
# 1397                       1      0
# 1345                       4      1
# 1144                       2      0
# 1989                       2      0
# 692                        4      0

# %% [markdown]
# How to sort a dataFrame using multiple variables (i.e columns) in ascending order and also in descending order?

# %%
data.sort_values(by=['Total day calls','Total eve calls'],ascending=False, inplace=True)
data.head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1121    MI              91        415                 No              No
# 468     AZ              86        415                 No             Yes
# 1460    MT              80        415                 No              No
# 315     MA              39        408                 No              No
# 1057    WV              86        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1121                    0.0              154.4              165
# 468                    32.0               70.9              163
# 1460                    0.0              198.1              160
# 315                     0.0               60.4              158
# 1057                   38.0              123.0              158
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1121             26.25              168.3              121             14.31
# 468              12.05              166.7              121             14.17
# 1460             33.68              156.7               87             13.32
# 315              10.27              306.2              120             26.03
# 1057             20.91              133.9              119             11.38
#
#       Total night minutes  Total night calls  Total night charge  \
# 1121                239.9                 81               10.80
# 468                 244.9                105               11.02
# 1460                182.1                 76                8.19
# 315                 123.9                 46                5.58
# 1057                138.2                103                6.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1121                11.7                 4               3.16
# 468                 11.1                 5               3.00
# 1460                 9.3                 3               2.51
# 315                 12.4                 3               3.35
# 1057                13.3                 4               3.59
#
#       Customer service calls  Churn
# 1121                       5      1
# 468                        3      0
# 1460                       3      0
# 315                        1      0
# 1057                       1      0

# %%
#Your answer here

data.sort_values(by=['Total day calls','Total eve calls'],ascending=True, inplace=True)
data.head()
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1121    MI              91        415                 No              No
# 468     AZ              86        415                 No             Yes
# 1460    MT              80        415                 No              No
# 315     MA              39        408                 No              No
# 1057    WV              86        415                 No             Yes
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1121                    0.0              154.4              165
# 468                    32.0               70.9              163
# 1460                    0.0              198.1              160
# 315                     0.0               60.4              158
# 1057                   38.0              123.0              158
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1121             26.25              168.3              121             14.31
# 468              12.05              166.7              121             14.17
# 1460             33.68              156.7               87             13.32
# 315              10.27              306.2              120             26.03
# 1057             20.91              133.9              119             11.38
#
#       Total night minutes  Total night calls  Total night charge  \
# 1121                239.9                 81               10.80
# 468                 244.9                105               11.02
# 1460                182.1                 76                8.19
# 315                 123.9                 46                5.58
# 1057                138.2                103                6.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1121                11.7                 4               3.16
# 468                 11.1                 5               3.00
# 1460                 9.3                 3               2.51
# 315                 12.4                 3               3.35
# 1057                13.3                 4               3.59
#
#       Customer service calls  Churn
# 1121                       5      1
# 468                        3      0
# 1460                       3      0
# 315                        1      0
# 1057                       1      0

# %% [markdown]
# <h2>Indexing and retrieving data</h2>
#
# What is the proportion of churned users in our dataframe?

# %%
#Your answer here
data['Churn'].sum()/data['Churn'].count()
# Out:
# 0.14491449144914492

# %% [markdown]
# What are average values of numerical features for churned users?

# %%
#Your answer here
data2=data[data['Churn']==1]
for i in data2.columns:
    if data[i].dtype!='object':
        print(i,data2[i].mean())
# Out:
# Account length 102.66459627329192
# Area code 437.8178053830228
# Number vmail messages 5.115942028985507
# Total day minutes 206.91407867494823
# Total day calls 101.33540372670808
# Total day charge 35.17592132505176
# Total eve minutes 212.41014492753624
# Total eve calls 100.56107660455487
# Total eve charge 18.05496894409938
# Total night minutes 205.23167701863352
# Total night calls 100.39958592132506
# Total night charge 9.23552795031056
# Total intl minutes 10.700000000000001
# Total intl calls 4.163561076604555
# Total intl charge 2.8895445134575573
# Customer service calls 2.229813664596273
# Churn 1.0

# %% [markdown]
# How much time (on average) do churned users spend on the phone during daytime?

# %%
#Your answer here
data2['Total day minutes'].mean()
# Out:
# 206.91407867494823

# %% [markdown]
# What is the maximum length of international calls among loyal users (`Churn == 0`) who do not have an international plan?

# %%
#Your answer here
data3=data[data['Churn']==0]
data3['Total intl minutes'].max()
# Out:
# 18.9

# %% [markdown]
# How to get the first or the last line of the data frame?

# %%
#Your answer here
data.head(1)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1121    MI              91        415                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1121                    0.0              154.4              165
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1121             26.25              168.3              121             14.31
#
#       Total night minutes  Total night calls  Total night charge  \
# 1121                239.9                 81                10.8
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1121                11.7                 4               3.16
#
#       Customer service calls  Churn
# 1121                       5      1

# %%
data.tail(1)
# Out:
#      State  Account length  Area code International plan Voice mail plan  \
# 1397    VT             101        510                 No              No
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1397                    0.0                0.0                0
#
#       Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 1397               0.0              192.1              119             16.33
#
#       Total night minutes  Total night calls  Total night charge  \
# 1397                168.8                 95                 7.6
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1397                 7.2                 4               1.94
#
#       Customer service calls  Churn
# 1397                       1      0

# %% [markdown]
# ### Applying Functions to Cells, Columns and Rows
#
# How can you apply a function to each column of a DataFrame to find the maximum value in each column?

# %%
#Your answer here
data.apply(np.max)
# Out:
# State                        WY
# Account length              243
# Area code                   510
# International plan          Yes
# Voice mail plan             Yes
# Number vmail messages      51.0
# Total day minutes         350.8
# Total day calls             165
# Total day charge          59.64
# Total eve minutes         363.7
# Total eve calls             170
# Total eve charge          30.91
# Total night minutes       395.0
# Total night calls           175
# Total night charge        17.77
# Total intl minutes         20.0
# Total intl calls             20
# Total intl charge           5.4
# Customer service calls        9
# Churn                         1
# dtype: object

# %% [markdown]
# How can you filter rows in a DataFrame to select all states that start with the letter "W"?

# %%
#Your answer here
for i in data['State']:
    if i[0]=='W':
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[93], line 2
#       1 #Your answer here
# ----> 2 data[data['State'][0]=='W'].head()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: False

# %% [markdown]
# How can you replace values in a DataFrame column, such as changing the values of "International plan" and "Voice mail plan" from "Yes" or "No" to True or False?

# %%
#Your answer here
d = {"No": False, "Yes": True}
data["Voice mail plan"] = data["Voice mail plan"].map(d)
data.head()
# Out:
#   State  Account length  Area code International plan  Voice mail plan  \
# 0    KS             128        415                 No             True
# 1    OH             107        415                 No             True
# 2    NJ             137        415                 No            False
# 3    OH              84        408                Yes            False
# 4    OK              75        415                Yes            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                   25.0              265.1              110
# 1                   26.0              161.6              123
# 2                    NaN              243.4              114
# 3                    NaN              299.4               71
# 4                    0.0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %%
data["International plan"] = data["International plan"].map(d)
data.head()
# Out:
#   State  Account length  Area code  International plan  Voice mail plan  \
# 0    KS             128        415               False             True
# 1    OH             107        415               False             True
# 2    NJ             137        415               False            False
# 3    OH              84        408                True            False
# 4    OK              75        415                True            False
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                   25.0              265.1              110
# 1                   26.0              161.6              123
# 2                    NaN              243.4              114
# 3                    NaN              299.4               71
# 4                    0.0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls  Churn
# 0                       1  False
# 1                       1  False
# 2                       0  False
# 3                       2  False
# 4                       3  False

# %% [markdown]
# ### Grouping
#
# In general, grouping data in Pandas works as follows:

# %% [markdown]
# ```python
# df.groupby(by=grouping_columns)[columns_to_show].function()
# ```

# %% [markdown]
# 1. First, the `groupby` method divides the `grouping_columns` by their values. They become a new index in the resulting dataframe.
# 2. Then, columns of interest are selected (`columns_to_show`). If `columns_to_show` is not included, all non groupby clauses will be included.
# 3. Finally, one or several functions are applied to the obtained groups per selected columns.
#
# How can you group data by a specific column (e.g., "Churn") and then display statistical summaries (e.g., mean, standard deviation, etc.) for selected columns such as "Total day minutes," "Total eve minutes," and "Total night minutes"?

# %%
#Your answer here
columns_to_show = ["Total day minutes", "Total eve minutes", "Total night minutes"]

data.groupby(["Churn"])[columns_to_show].describe(percentiles=[])
# Out:
#       Total day minutes                                  Total eve minutes  \
#                   count    mean   std  min    50%    max             count
# Churn
# 0                2846.0  175.18  50.2  0.0  177.2  315.6            2850.0
# 1                 483.0  206.91  69.0  0.0  217.6  350.8             483.0
#
#                                          Total night minutes                 \
#          mean    std   min    50%    max               count    mean    std
# Churn
# 0      199.04  50.29   0.0  199.6  361.8              2850.0  200.13  51.11
# 1      212.41  51.73  70.9  211.3  363.7               483.0  205.23  47.13
#
#
#         min     50%    max
# Churn
# 0      23.2  200.25  395.0
# 1      47.4  204.80  354.9

# %% [markdown]
# How can you group data by a specific column (e.g., "Churn") and then apply multiple aggregation functions (e.g., mean, standard deviation, min, max) to selected columns such as "Total day minutes," "Total eve minutes," and "Total night minutes"?

# %%
#Your answer here
columns_to_show = ["Total day minutes", "Total eve minutes", "Total night minutes"]

data.groupby(["Churn"])[columns_to_show].agg([np.mean, np.std, np.min, np.max])
# Out:
#       Total day minutes                   Total eve minutes               \
#                    mean   std  min    max              mean    std   min
# Churn
# 0                175.18  50.2  0.0  315.6            199.04  50.29   0.0
# 1                206.91  69.0  0.0  350.8            212.41  51.73  70.9
#
#              Total night minutes
#          max                mean    std   min    max
# Churn
# 0      361.8              200.13  51.11  23.2  395.0
# 1      363.7              205.23  47.13  47.4  354.9

# %% [markdown]
# ### Summary tables
#
# How can you create a contingency table to observe the distribution of data across two variables, such as "Churn" and "International plan"?

# %%
#Your answer here
pd.crosstab(data["Churn"], data["International plan"])
# Out:
# International plan  False  True
# Churn
# 0                    2664    186
# 1                     346    137

# %% [markdown]
# How can you create a contingency table to observe the distribution of data across two variables, such as "Churn" and "Voice mail plan"?

# %%
#Your answer here
pd.crosstab(data["Churn"], data["Voice mail plan"])
# Out:
# Voice mail plan  False  True
# Churn
# 0                 2008    842
# 1                  403     80

# %% [markdown]
# How can you create a pivot table to calculate the average number of day, evening, and night calls grouped by "Area code"?

# %%
#Your answer here
data.pivot_table(
    ["Total day calls", "Total eve calls", "Total night calls"],
    ["Area code"],
    aggfunc="mean",
)
# Out:
#            Total day calls  Total eve calls  Total night calls
# Area code
# 408                 100.50            99.79              99.04
# 415                 100.58           100.50             100.40
# 510                 100.10            99.67             100.60

# %% [markdown]
# ### DataFrame transformations
#
# How can you calculate the total number of calls ("Total day calls", "Total eve calls", "Total night calls", and "Total intl calls") for all users and add this information as a new column named "Total calls" to the DataFrame?

# %%
#Your answer here
total_calls = (
    data["Total day calls"]
    + data["Total eve calls"]
    + data["Total night calls"]
    + data["Total intl calls"]
)
data.insert(loc=len(data.columns), column="Total calls", value=total_calls)
data.head()
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 1121    MI              91        415               False            False
# 468     AZ              86        415               False             True
# 1460    MT              80        415               False            False
# 2392    WY              90        510               False            False
# 1057    WV              86        415               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1121                    0.0              154.4              165
# 468                    32.0               70.9              163
# 1460                    0.0              198.1              160
# 2392                    0.0              125.4              158
# 1057                   38.0              123.0              158
#
#       Total day charge  Total eve minutes  ...  Total night minutes  \
# 1121             26.25              168.3  ...                239.9
# 468              12.05              166.7  ...                244.9
# 1460             33.68              156.7  ...                182.1
# 2392             21.32              269.1  ...                238.6
# 1057             20.91              133.9  ...                138.2
#
#       Total night calls  Total night charge  Total intl minutes  \
# 1121                 81               10.80                11.7
# 468                 105               11.02                11.1
# 1460                 76                8.19                 9.3
# 2392                103               10.74                11.0
# 1057                103                6.22                13.3
#
#       Total intl calls  Total intl charge  Customer service calls  Churn  \
# 1121                 4               3.16                       5      1
# 468                  5               3.00                       3      0
# 1460                 3               2.51                       3      0
# 2392                 7               2.97                       1      0
# 1057                 4               3.59                       1      0
#
#       Total call  Total calls
# 1121         371          371
# 468          394          394
# 1460         326          326
# 2392         351          351
# 1057         384          384
#
# [5 rows x 22 columns]

# %% [markdown]
# How can you delete specific columns or rows from a DataFrame?
# **Note:** It should alters the current DataFrame and should not return a new one.

# %%
#Your answer here
data.drop(["Total calls"], axis=1, inplace=True)
data.head()
# Out:
#      State  Account length  Area code  International plan  Voice mail plan  \
# 1121    MI              91        415               False            False
# 468     AZ              86        415               False             True
# 1460    MT              80        415               False            False
# 2392    WY              90        510               False            False
# 1057    WV              86        415               False             True
#
#       Number vmail messages  Total day minutes  Total day calls  \
# 1121                    0.0              154.4              165
# 468                    32.0               70.9              163
# 1460                    0.0              198.1              160
# 2392                    0.0              125.4              158
# 1057                   38.0              123.0              158
#
#       Total day charge  Total eve minutes  ...  Total eve charge  \
# 1121             26.25              168.3  ...             14.31
# 468              12.05              166.7  ...             14.17
# 1460             33.68              156.7  ...             13.32
# 2392             21.32              269.1  ...             22.87
# 1057             20.91              133.9  ...             11.38
#
#       Total night minutes  Total night calls  Total night charge  \
# 1121                239.9                 81               10.80
# 468                 244.9                105               11.02
# 1460                182.1                 76                8.19
# 2392                238.6                103               10.74
# 1057                138.2                103                6.22
#
#       Total intl minutes  Total intl calls  Total intl charge  \
# 1121                11.7                 4               3.16
# 468                 11.1                 5               3.00
# 1460                 9.3                 3               2.51
# 2392                11.0                 7               2.97
# 1057                13.3                 4               3.59
#
#       Customer service calls  Churn  Total call
# 1121                       5      1         371
# 468                        3      0         394
# 1460                       3      0         326
# 2392                       1      0         351
# 1057                       1      0         384
#
# [5 rows x 21 columns]

# %% [markdown]
# <h1> Visualizing the Data</h1>
#
# We'll do this using visual analysis with `matplotlib` and `Seaborn`.

# %%
# some imports to set up plotting
import matplotlib.pyplot as plt
# !pip install seaborn
import seaborn as sns

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# How can you create a count plot to visualize the distribution of the "International plan" variable, with separate bars for each "Churn" category,

# %%
#Your answer here
sns.countplot(x="International plan", hue="Churn", data=data);

# %% [markdown]
# <h2> Univariate visualization</h2>
#
# *Univariate* analysis looks at one feature at a time. When we analyze a feature independently, we are usually mostly interested in the *distribution of its values* and ignore other features in the dataset.
#
# Create histograms to visualize the distribution of values for the features "Total day minutes" and "Total intl calls"?

# %%
sns.histplot(x='Total day minutes', hue="Churn", data=data);

# %%
#Your answer here

sns.histplot(x='Total intl calls', data=data);

# %% [markdown]
# Create density plots to visualize the distribution of values for the features "Total day minutes" and "Total intl calls"?

# %%
sns.histplot(x='Total intl calls', data=data,kde=True);

# %%
#Your answer here
sns.histplot(x='Total day minutes', data=data,kde=True);

# %% [markdown]
# Create a box plot to visualize the distribution of the "Total intl calls" feature

# %%
#Your answer here
sns.boxplot(x='Total intl calls', data=data);

# %% [markdown]
# Make a comparison between a box plot and a violin plot for visualizing the distribution of the "Total intl calls" feature.

# %%
#Your answer here
sns.violinplot(x='Total intl calls',  data=data);

# %% [markdown]
# <h2>Multivariate visualization</h2>
#
# Create a correlation matrix to visualize the relationships among numerical variables in a DataFrame, and display it using a heatmap?

# %%
#Your answer here
dataframe = pd.DataFrame(data, columns=['Account length', 'Area code',  'Number vmail messages', 'Total day minutes',
       'Total day calls', 'Total day charge', 'Total eve minutes',
       'Total eve calls', 'Total eve charge', 'Total night minutes'])
matrix = dataframe.corr()
print(matrix)
# Out:
#                        Account length  Area code  Number vmail messages  \
# Account length               1.00e+00  -1.25e-02              -4.40e-03
# Area code                   -1.25e-02   1.00e+00              -2.12e-03
# Number vmail messages       -4.40e-03  -2.12e-03               1.00e+00
# Total day minutes            5.45e-03  -9.13e-03               1.30e-03
# Total day calls              3.85e-02  -9.65e-03              -9.61e-03
# Total day charge             6.21e-03  -8.26e-03               1.16e-03
# Total eve minutes           -6.76e-03   3.58e-03               1.65e-02
# Total eve calls              1.93e-02  -1.19e-02              -5.95e-03
# Total eve charge            -6.75e-03   3.61e-03               1.65e-02
# Total night minutes         -8.96e-03  -5.82e-03               7.28e-03
#
#                        Total day minutes  Total day calls  Total day charge  \
# Account length                  5.45e-03         3.85e-02          6.21e-03
# Area code                      -9.13e-03        -9.65e-03         -8.26e-03
# Number vmail messages           1.30e-03        -9.61e-03          1.16e-03
# Total day minutes               1.00e+00         7.04e-03          1.00e+00
# Total day calls                 7.04e-03         1.00e+00          6.75e-03
# Total day charge                1.00e+00         6.75e-03          1.00e+00
# Total eve minutes               6.54e-03        -2.15e-02          7.05e-03
# Total eve calls                 1.56e-02         6.46e-03          1.58e-02
# Total eve charge                6.53e-03        -2.14e-02          7.04e-03
# Total night minutes             3.93e-03         2.29e-02          4.32e-03
#
#                        Total eve minutes  Total eve calls  Total eve charge  \
# Account length                 -6.76e-03         1.93e-02         -6.75e-03
# Area code                       3.58e-03        -1.19e-02          3.61e-03
# Number vmail messages           1.65e-02        -5.95e-03          1.65e-02
# Total day minutes               6.54e-03         1.56e-02          6.53e-03
# Total day calls                -2.15e-02         6.46e-03         -2.14e-02
# Total day charge                7.05e-03         1.58e-02          7.04e-03
# Total eve minutes               1.00e+00        -1.14e-02          1.00e+00
# Total eve calls                -1.14e-02         1.00e+00         -1.14e-02
# Total eve charge                1.00e+00        -1.14e-02          1.00e+00
# Total night minutes            -1.26e-02        -2.09e-03         -1.26e-02
#
#                        Total night minutes
# Account length                   -8.96e-03
# Area code                        -5.82e-03
# Number vmail messages             7.28e-03
# Total day minutes                 3.93e-03
# Total day calls                   2.29e-02
# Total day charge                  4.32e-03
# Total eve minutes                -1.26e-02
# Total eve calls                  -2.09e-03
# Total eve charge                 -1.26e-02
# Total night minutes               1.00e+00

# %% [markdown]
# ##### Scatter plot
#
# Create a scatter plot to visualize the relationship between two numerical variables, such as "Total day minutes" and "Total night minutes,"?

# %%
#Your answer here
sns.scatterplot(x='Total day minutes',y='Total night minutes',  data=data);

# %% [markdown]
# Create a scatter plot with different colors for the "Churn" categories to visualize the relationship between "Total day minutes" and "Total night minutes"

# %%
#Your answer here
sns.scatterplot(x='Total day minutes',y='Total night minutes', hue="Churn", data=data);

# %% [markdown]
# Create a count plot to visualize the distribution of the "Customer service calls" variable, with different colors representing the "Churn" categories.

# %%
#Your answer here
sns.countplot(x='Customer service calls',hue='Churn'  ,data=data);

# %% [markdown]
# <h1>Data Transformation</h1>

# %%
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# Delete specific columns ( "Churn", "State" ) from a DataFrame, convert binary categorical values ("Yes"/"No") into numerical values

# %%
#Your answer here
data.drop([ "Churn", "State"], axis=1, inplace=True)
data.head()
# Out:
#    Account length  Area code International plan Voice mail plan  \
# 0             128        415                 No             Yes
# 1             107        415                 No             Yes
# 2             137        415                 No              No
# 3              84        408                Yes              No
# 4              75        415                Yes              No
#
#    Number vmail messages  Total day minutes  Total day calls  \
# 0                   25.0              265.1              110
# 1                   26.0              161.6              123
# 2                    NaN              243.4              114
# 3                    NaN              299.4               71
# 4                    0.0              166.7              113
#
#    Total day charge  Total eve minutes  Total eve calls  Total eve charge  \
# 0             45.07              197.4               99             16.78
# 1             27.47              195.5              103             16.62
# 2             41.38              121.2              110             10.30
# 3             50.90               61.9               88              5.26
# 4             28.34              148.3              122             12.61
#
#    Total night minutes  Total night calls  Total night charge  \
# 0                244.7                 91               11.01
# 1                254.4                103               11.45
# 2                162.6                104                7.32
# 3                196.9                 89                8.86
# 4                186.9                121                8.41
#
#    Total intl minutes  Total intl calls  Total intl charge  \
# 0                10.0                 3               2.70
# 1                13.7                 3               3.70
# 2                12.2                 5               3.29
# 3                 6.6                 7               1.78
# 4                10.1                 3               2.73
#
#    Customer service calls
# 0                       1
# 1                       1
# 2                       0
# 3                       2
# 4                       3

# %%
df_one = pd.get_dummies(dataframe)
print(df_one)
# Out:
#       Account length  Area code  Number vmail messages  Total day minutes  \
# 1121              91        415                    0.0              154.4
# 468               86        415                   32.0               70.9
# 1460              80        415                    0.0              198.1
# 2392              90        510                    0.0              125.4
# 1057              86        415                   38.0              123.0
# ...              ...        ...                    ...                ...
# 692               82        408                    0.0              185.8
# 1989             124        415                   30.0              144.5
# 1144             155        408                    0.0              216.7
# 1397             101        510                    0.0                0.0
# 1345              98        415                    0.0                0.0
#
#       Total day calls  Total day charge  Total eve minutes  Total eve calls  \
# 1121              165             26.25              168.3              121
# 468               163             12.05              166.7              121
# 1460              160             33.68              156.7               87
# 2392              158             21.32              269.1               83
# 1057              158             20.91              133.9              119
# ...               ...               ...                ...              ...
# 692                36             31.59              276.5              134
# 1989               35             24.57              262.3              101
# 1144               30             36.84              144.3              125
# 1397                0              0.00              192.1              119
# 1345                0              0.00              159.6              130
#
#       Total eve charge  Total night minutes
# 1121             14.31                239.9
# 468              14.17                244.9
# 1460             13.32                182.1
# 2392             22.87                238.6
# 1057             11.38                138.2
# ...                ...                  ...
# 692              23.50                192.1
# 1989             22.30                226.5
# 1144             12.27                135.3
# 1397             16.33                168.8
# 1345             13.57                167.1
#
# [3333 rows x 10 columns]

# %% [markdown]
# Now normalize the feature data by subtracting the mean and dividing by the standard deviation, and then convert the scaled data into a DataFrame

# %%
#Your answer here

# %% [markdown]
# <h1>Splitting a Dataset into Train & Test Set</h1>
#
# How can you split a dataset into training and testing sets, with 25% of the data reserved for testing?

# %%
#Your answer here
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
 
data6=data.dropna()
 
X_train, X_test, y_train, y_test = train_test_split(data6.drop('Churn',axis=1),data6['Churn'] ,test_size=0.25, random_state=0)

# %% [markdown]
# <h1>Classification using Machine Learning</h1>

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# Train a Decision Tree classifier on the training data and make predictions on the test data

# %%
#Your answer here
clf = DecisionTreeClassifier()
clf = clf.fit(X_train.drop('State',axis=1),y_train)

# %% [markdown]
# **Some additional questions**
#
# 1) If you will be asked to choose a single feature for classification which one you will choose.
# Justify with analysis.

# %%
#Your answer here
y_pred_gini = clf.predict(X_test.drop('State',axis=1))
print(y_pred_gini)
# Out:
# [False False  True False False  True False False False False False False
#  False False False False False False False False False  True False False
#  False  True False False False False False False  True False False False
#  False False False False False False False False False  True  True False
#  False False False  True  True  True False False False False False False
#   True  True False False  True False False False False False False False
#  False False False False False  True False False False  True False False
#  False False  True False False False False False False False False False
#   True False False False False False False False False False False False
#  False  True  True False False False False False False False False False
#  False False False False False  True False  True False False False False
#  False False False False False False False False False  True False False
#   True False False False False False False False False False  True False
#  False False  True False  True  True False False False False  True False
#  False False False  True False False False False False False False False
#  False  True False False  True False False False False False False False
#  False False False  True False False False False  True False  True False
#  False  True  True False False False False False False  True  True False
#  False False  True False  True False False  True False False False False
#  False False False False False False False False  True False False False
#  False False False False False  True False False  True False False False
#  False False False False False  True False False False  True False False
#  False False  True False False False False False  True False False False
#  False False False False False  True False  True False False False False
#   True False False  True False False False False False False False False
#  False False False False False False False False False False False False
#   True False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False  True False False  True  True False False False False False
#  False False False False False False False False False False False  True
#  False False False False False False False False False False False False
#  False  True False False False False False False  True False False False
#  False False False False False False False False False  True  True False
#  False False False False False  True False False False False False False
#  False False False False False  True False False False  True False False
#  False False False False False False  True False False False  True False
#  False  True False False False False False False False  True False False
#  False False False  True False False False False False False False False
#   True False False False False False False False False  True False  True
#  False False False False False False False False False False  True  True
#   True False False False False False False  True False False False False
#  False False False False False False False False False  True  True False
#  False False False False False False False False False False False False
#  False False False False False False False False  True False False  True
#  False False False False False  True False False  True False False False
#  False  True False  True False  True False False False False False  True
#  False False  True False False  True False False False False False False
#  False False False False False False False False False False False False
#   True False False False False False  True False False False False False
#  False False False False False  True False False False False False False
#  False False False  True False False False False False False False False
#  False False False False False False False  True False False False  True
#  False False False False False False  True False False False False  True
#  False False  True False False  True False False  True False False False
#  False  True False False False False False False False False False False
#  False False False False False False False  True False False  True False
#  False False  True False False False False False False False False False
#   True False False False False  True False False False  True False False
#  False False False False False False False False False False False  True
#  False False False  True False  True False False False  True False False
#  False False False False False False False False False False False False
#  False  True False  True False False False False False False False  True
#  False False  True False  True False False  True False False False False
#  False False False False False  True False  True  True  True False False
#  False False False False False False False False  True False False False
#  False  True False False  True False False False False False False False
#  False False False False  True False False False False False False False
#  False  True False False False False False False False False False False
#  False False  True]

# %% [markdown]
# 2) If you will be asked to choose two features for classification which two you will choose.
# Justify with analysis.

# %%
#Your answer here
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred_gini)
print(acc)
# Out:
# 0.9037304452466908
