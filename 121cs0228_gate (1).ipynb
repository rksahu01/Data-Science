# %%
#Q1
2-4-1 EXOR

# %%
#Initializing x and y with numpy
import numpy as np
X=np.array(([0,0],[0,1],[1,0],[1,1]), dtype=float)
y=np.array(([0],[1],[1],[0]), dtype=float)

# sigmoid  function
def sigmoid(t):
    '''This will return the sigmoid value of the function'''
    return 1/(1+np.exp(-t))
# derivative sigmoid
def sigmoid_derivative(d):
    return d * (1 - d)

# %%
# Class definition
class NeuralNetwork:
    def __init__(self, x,y):
        self.input = x #initializing x
        self.weights1= np.random.rand(self.input.shape[1],4) #initializing random weights
        self.weights2 = np.random.rand(4,1)#considering we have 4 nodes in the hidden layer
        self.y = y#initializing y
        self.output = np. zeros(y.shape)#initializing the output
        
    def feedforward(self):
        '''This will perform the forward propagation for the next 2 layers'''
        self.layer1 = sigmoid(np.dot(self.input, self.weights1))#calcuation of w_T*X+b for layer1
        self.layer2 = sigmoid(np.dot(self.layer1, self.weights2))#calcuation of w_T*X+b for layer2
        return self.layer2
        
    def backprop(self):
        '''Back propagation of the final hidden layers to initial layers'''
        derv_weights2 = np.dot(self.layer1.T, 2*(self.y -self.output)*sigmoid_derivative(self.output))#backpropagation of layer2
        derv_weights1 = np.dot(self.input.T, np.dot(2*(self.y -self.output)*sigmoid_derivative(self.output), self.weights2.T)*sigmoid_derivative(self.layer1))
    
        self.weights1 += derv_weights1#updation of weight matrix of layer1
        self.weights2 += derv_weights2#updation of weight matrix of layer2

    def train(self, X, y):
        self.output = self.feedforward()#Forward Propagation
        self.backprop()#Backward Propagation

# %%
model=NeuralNetwork(X,y)
itr=list(range(1500))
loss=[0]*1500
for i in range(1500):
    loss[i]=np.mean(np.square(y - model.feedforward()))
    if i % 100 ==0:#For each 100 epochs output will come 
        print ("for iteration # " + str(i) + "\n")
        print ("Input : \n" + str(X))
        print ("Actual Output: \n" + str(y))
        print ("Predicted Output: \n" + str(model.feedforward()))
        print ("Loss: \n" + str(np.mean(np.square(y - model.feedforward())))) # mean sum squared loss
        print ("\n")
  
    model.train(X, y)
# Out:
# for iteration # 0
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.6625117]
#  [0.6828794]
#  [0.6832351]
#  [0.7012124]]
# Loss:
# 0.28288151451747273
#
#
# for iteration # 100
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.48059258]
#  [0.49606287]
#  [0.5224377 ]
#  [0.51999974]]
# Loss:
# 0.24584683336650348
#
#
# for iteration # 200
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.31733633]
#  [0.62374136]
#  [0.65258932]
#  [0.42325998]]
# Loss:
# 0.13552902466131966
#
#
# for iteration # 300
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.1787358 ]
#  [0.84066914]
#  [0.8382748 ]
#  [0.15214468]]
# Loss:
# 0.0266589634986716
#
#
# for iteration # 400
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.1295317 ]
#  [0.89516275]
#  [0.89276527]
#  [0.09126924]]
# Loss:
# 0.011899667565104919
#
#
# for iteration # 500
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.10502923]
#  [0.91738124]
#  [0.91556602]
#  [0.06907692]]
# Loss:
# 0.007439428498369653
#
#
# for iteration # 600
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.08973932]
#  [0.92990199]
#  [0.92866421]
#  [0.05757023]]
# Loss:
# 0.0053425006514295215
#
#
# for iteration # 700
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.07901995]
#  [0.93814672]
#  [0.93742186]
#  [0.05046237]]
# Loss:
# 0.004133113784587115
#
#
# for iteration # 800
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.07095594]
#  [0.94409174]
#  [0.94381206]
#  [0.04558698]]
# Loss:
# 0.0033489341369112783
#
#
# for iteration # 900
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.06459748]
#  [0.94864163]
#  [0.94874556]
#  [0.04199908]]
# Loss:
# 0.0028003642063799423
#
#
# for iteration # 1000
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.05941368]
#  [0.95227384]
#  [0.95270703]
#  [0.03922028]]
# Loss:
# 0.0023956566417858757
#
#
# for iteration # 1100
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.05508162]
#  [0.95526618]
#  [0.955981  ]
#  [0.03698228]]
# Loss:
# 0.002085115100021685
#
#
# for iteration # 1200
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.05139212]
#  [0.95779222]
#  [0.95874689]
#  [0.03512287]]
# Loss:
# 0.0018395202849042962
#
#
# for iteration # 1300
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.04820282]
#  [0.95996638]
#  [0.96112422]
#  [0.03353831]]
# Loss:
# 0.0016405867453496154
#
#
# for iteration # 1400
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.04541296]
#  [0.96186736]
#  [0.96319609]
#  [0.03215933]]
# Loss:
# 0.001476296466846807

# %%
import seaborn as sns
sns.lineplot(x=itr,y=loss)
# Out:
# <Axes: >

# %%
#Q2
#2-6-1 EXOR

X2=np.array(([0,0],[0,1],[1,0],[1,1]), dtype=float)
y2=np.array(([0],[1],[1],[0]), dtype=float)

# Class definition
class NeuralNetwork2:
    def __init__(self, x,y):
        self.input = x #initializing x
        self.weights1= np.random.rand(self.input.shape[1],6) #initializing random weights
        self.weights2 = np.random.rand(6,1)#considering we have 6 nodes in the hidden layer
        self.y = y#initializing y
        self.output = np. zeros(y.shape)#initializing the output
        
    def feedforward(self):
        '''This will perform the forward propagation for the next 2 layers'''
        self.layer1 = sigmoid(np.dot(self.input, self.weights1))#calcuation of w_T*X+b for layer1
        self.layer2 = sigmoid(np.dot(self.layer1, self.weights2))#calcuation of w_T*X+b for layer2
        return self.layer2
        
    def backprop(self):
        '''Back propagation of the final hidden layers to initial layers'''
        derv_weights2 = np.dot(self.layer1.T, 2*(self.y -self.output)*sigmoid_derivative(self.output))#backpropagation of layer2
        derv_weights1 = np.dot(self.input.T, np.dot(2*(self.y -self.output)*sigmoid_derivative(self.output), self.weights2.T)*sigmoid_derivative(self.layer1))
       
        self.weights1 += derv_weights1#updation of weight matrix of layer1
        self.weights2 += derv_weights2#updation of weight matrix of layer2

    def train(self, X, y):
        self.output = self.feedforward()#Forward Propagation
        self.backprop()#Backward Propagation

# %%
model=NeuralNetwork2(X,y)
itr=list(range(1500))
loss=[0]*1500
for i in range(1500):
    loss[i]=np.mean(np.square(y - model.feedforward()))
    if i % 100 ==0:#For each 100 epochs output will come 
        print ("for iteration # " + str(i) + "\n")
        print ("Input : \n" + str(X))
        print ("Actual Output: \n" + str(y))
        print ("Predicted Output: \n" + str(model.feedforward()))
        print ("Loss: \n" + str(np.mean(np.square(y - model.feedforward())))) # mean sum squared loss
        print ("\n")
  
    model.train(X2, y2)
# Out:
# for iteration # 0
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.84016647]
#  [0.89404484]
#  [0.87582816]
#  [0.91550595]]
# Loss:
# 0.39266899752456463
#
#
# for iteration # 100
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.48762302]
#  [0.51096245]
#  [0.50376006]
#  [0.5146878 ]]
# Loss:
# 0.2470228871728946
#
#
# for iteration # 200
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.30649996]
#  [0.62488316]
#  [0.62124692]
#  [0.45923429]]
# Loss:
# 0.14725122323621487
#
#
# for iteration # 300
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.17463939]
#  [0.7944456 ]
#  [0.79820716]
#  [0.22583324]]
# Loss:
# 0.04111813250886288
#
#
# for iteration # 400
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.12073296]
#  [0.87816081]
#  [0.88499465]
#  [0.11805034]]
# Loss:
# 0.014145837111066989
#
#
# for iteration # 500
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.09686654]
#  [0.90902785]
#  [0.9153011 ]
#  [0.08222095]]
# Loss:
# 0.007898312087175686
#
#
# for iteration # 600
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.08293314]
#  [0.92499923]
#  [0.93059602]
#  [0.06490653]]
# Loss:
# 0.005383197971745768
#
#
# for iteration # 700
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.07354096]
#  [0.93498145]
#  [0.94002022]
#  [0.05463329]]
# Loss:
# 0.004054513517594652
#
#
# for iteration # 800
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.06665736]
#  [0.94193007]
#  [0.94652236]
#  [0.04777422]]
# Loss:
# 0.003239388930203499
#
#
# for iteration # 900
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.06133017]
#  [0.94710951]
#  [0.95134124]
#  [0.04283479]]
# Loss:
# 0.0026903218482769702
#
#
# for iteration # 1000
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.057047  ]
#  [0.95115611]
#  [0.95509211]
#  [0.03908638]]
# Loss:
# 0.0022961373890313936
#
#
# for iteration # 1100
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.05350451]
#  [0.95442768]
#  [0.95811741]
#  [0.03613057]]
# Loss:
# 0.001999784366614744
#
#
# for iteration # 1200
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.05051012]
#  [0.95714229]
#  [0.9606241 ]
#  [0.03373051]]
# Loss:
# 0.0017690660077893346
#
#
# for iteration # 1300
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.04793489]
#  [0.95944117]
#  [0.96274529]
#  [0.03173627]]
# Loss:
# 0.0015844692991310591
#
#
# for iteration # 1400
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.04568878]
#  [0.9614202 ]
#  [0.96457087]
#  [0.03004808]]
# Loss:
# 0.0014334938939458935

# %%
import seaborn as sns
sns.lineplot(x=itr,y=loss)
# Out:
# <Axes: >

# %%
#Q3
#2-6-1 EXOR bias

X2=np.array(([0,0],[0,1],[1,0],[1,1]), dtype=float)
y2=np.array(([0],[1],[1],[0]), dtype=float)

# Class definition
class NeuralNetwork3:
    def __init__(self, x,y):
        self.input = x #initializing x
        self.weights1= np.random.rand(self.input.shape[1],6) #initializing random weights
        self.weights2 = np.random.rand(6,1)#considering we have 6 nodes in the hidden layer
        self.bias1=np.random.rand(6,1)
        self.bias2=np.random.rand(1,1)
        self.y = y#initializing y
        self.output = np. zeros(y.shape)#initializing the output
        
    def feedforward(self):
        '''This will perform the forward propagation for the next 2 layers'''
        self.layer1 = sigmoid(np.dot(self.input, self.weights1)+np.mean(self.bias1))#calcuation of w_T*X+b for layer1
        self.layer2 = sigmoid(np.dot(self.layer1, self.weights2)+np.mean(self.bias2))#calcuation of w_T*X+b for layer2
        return self.layer2
        
    def backprop(self):
        '''Back propagation of the final hidden layers to initial layers'''
        derv_weights2 = np.dot(self.layer1.T, 2*(self.y -self.output)*sigmoid_derivative(self.output))#backpropagation of layer2
        derv_weights1 = np.dot(self.input.T, np.dot(2*(self.y -self.output)*sigmoid_derivative(self.output), self.weights2.T)*sigmoid_derivative(self.layer1))
        t_bias2=np.dot(self.bias1, 2*(self.y -self.output)*sigmoid_derivative(self.output))
        t_bias1= np.dot(self.input.T, np.dot(2*(self.y -self.output)*sigmoid_derivative(self.output), self.weights2.T)*sigmoid_derivative(self.bias1))
    
        self.weights1 += derv_weights1#updation of weight matrix of layer1
        self.weights2 += derv_weights2#updation of weight matrix of layer2
        bias1+=t_bias1
        bias2+=t_bias2

    def train(self, X, y):
        self.output = self.feedforward()#Forward Propagation
        self.backprop()#Backward Propagation

# %%
model=NeuralNetwork(X2,y2)
itr=list(range(1500))
loss=[0]*1500
for i in range(1500):
    loss[i]=np.mean(np.square(y - model.feedforward()))
    if i % 100 ==0:#For each 100 epochs output will come 
        print ("for iteration # " + str(i) + "\n")
        print ("Input : \n" + str(X))
        print ("Actual Output: \n" + str(y))
        print ("Predicted Output: \n" + str(model.feedforward()))
        print ("Loss: \n" + str(np.mean(np.square(y - model.feedforward())))) # mean sum squared loss
        print ("\n")
  
    model.train(X2, y2)
# Out:
# for iteration # 0
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.67959548]
#  [0.72600915]
#  [0.69457482]
#  [0.73727587]]
# Loss:
# 0.293445313605683
#
#
# for iteration # 100
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.47370562]
#  [0.51523977]
#  [0.50947795]
#  [0.53120669]]
# Loss:
# 0.2455454797374809
#
#
# for iteration # 200
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.35109158]
#  [0.60397195]
#  [0.60684709]
#  [0.48386132]]
# Loss:
# 0.1671986255694603
#
#
# for iteration # 300
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.21140818]
#  [0.76932655]
#  [0.77004015]
#  [0.25676022]]
# Loss:
# 0.05417775073021816
#
#
# for iteration # 400
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.13773534]
#  [0.88083931]
#  [0.88407068]
#  [0.10806735]]
# Loss:
# 0.014572113047065686
#
#
# for iteration # 500
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.10858704]
#  [0.91160524]
#  [0.91421782]
#  [0.07418613]]
# Loss:
# 0.008116735859793521
#
#
# for iteration # 600
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.09187369]
#  [0.92690888]
#  [0.928926  ]
#  [0.05929439]]
# Loss:
# 0.0055876059085647875
#
#
# for iteration # 700
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.08061073]
#  [0.93650317]
#  [0.93800636]
#  [0.05079602]]
# Loss:
# 0.004238346155989765
#
#
# for iteration # 800
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.07232359]
#  [0.94326172]
#  [0.94432316]
#  [0.04523774]]
# Loss:
# 0.003399074418303935
#
#
# for iteration # 900
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.06587821]
#  [0.94836777]
#  [0.94904809]
#  [0.0412808 ]]
# Loss:
# 0.0028265068293879788
#
#
# for iteration # 1000
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.06067018]
#  [0.95240923]
#  [0.9527596 ]
#  [0.03829441]]
# Loss:
# 0.0024109673520777706
#
#
# for iteration # 1100
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.05634329]
#  [0.95571586]
#  [0.95577998]
#  [0.0359413 ]]
# Loss:
# 0.0020957096806604254
#
#
# for iteration # 1200
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.05267186]
#  [0.9584891 ]
#  [0.95830461]
#  [0.03402434]]
# Loss:
# 0.0018484102705362455
#
#
# for iteration # 1300
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.04950484]
#  [0.96085999]
#  [0.96045962]
#  [0.03242042]]
# Loss:
# 0.0016492989578732976
#
#
# for iteration # 1400
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.04673673]
#  [0.96291808]
#  [0.96233044]
#  [0.03104865]]
# Loss:
# 0.00148560118473804

# %%
import seaborn as sns
sns.lineplot(x=itr,y=loss)
# Out:
# <Axes: >

# %%
def relu(t):
    '''This will return the relu value of the function'''
    np.maximum(0,t)
# derivative sigmoid
def relu_derivative(d):
    np.where(d>0,1,0)

# %%
#Q4
#2-6-1 EXOR bias re

X2=np.array(([0,0],[0,1],[1,0],[1,1]), dtype=float)
y2=np.array(([0],[1],[1],[0]), dtype=float)

# Class definition
class NeuralNetwork5:
    def __init__(self, x,y):
        self.input = x #initializing x
        self.weights1= np.random.rand(self.input.shape[1],6) #initializing random weights
        self.weights2 = np.random.rand(6,1)#considering we have 6 nodes in the hidden layer
        self.bias1=np.random.rand(6,1)
        self.bias2=np.random.rand(1,1)
        self.y = y#initializing y
        self.output = np. zeros(y.shape)#initializing the output
        
    def feedforward(self):
        '''This will perform the forward propagation for the next 2 layers'''
        self.layer1 = relu(np.dot(self.input, self.weights1))#calcuation of w_T*X+b for layer1
        self.layer2 = sigmoid(np.dot(self.layer1, self.weights2))#calcuation of w_T*X+b for layer2
        return self.layer2
        
    def backprop(self):
        '''Back propagation of the final hidden layers to initial layers'''
        derv_weights2 = np.dot(self.layer1.T, 2*(self.y -self.output)*rsigmoid_derivative(self.output))#backpropagation of layer2
        derv_weights1 = np.dot(self.input.T, np.dot(2*(self.y -self.output)*srelu_derivative(self.output), self.weights2.T)*relu_derivative(self.layer1))
        t_bias2=np.dot(self.bias1, 2*(self.y -self.output)*sigmoid_derivative(self.output))
        t_bias1= np.dot(self.input.T, np.dot(2*(self.y -self.output)*relu_derivative(self.output), self.weights2.T)*relu_derivative(self.bias1))
    
        self.weights1 += derv_weights1#updation of weight matrix of layer1
        self.weights2 += derv_weights2#updation of weight matrix of layer2
        bias1+=t_bias1
        bias2+=t_bias2

    def train(self, X, y):
        self.output = self.feedforward()#Forward Propagation
        self.backprop()#Backward Propagation

# %%
model=NeuralNetwork(X2,y2)
itr=list(range(100))
loss=[0]*100
for i in range(100):
    loss[i]=np.mean(np.square(y - model.feedforward()))
    if i % 100 ==0:#For each 100 epochs output will come 
        print ("for iteration # " + str(i) + "\n")
        print ("Input : \n" + str(X))
        print ("Actual Output: \n" + str(y))
        print ("Predicted Output: \n" + str(model.feedforward()))
        print ("Loss: \n" + str(np.mean(np.square(y - model.feedforward())))) # mean sum squared loss
        print ("\n")
  
    model.train(X2, y2)
# Out:
# for iteration # 0
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.79619933]
#  [0.83693915]
#  [0.84361471]
#  [0.87339681]]
# Loss:
# 0.36195014256101676

# %%
import seaborn as sns
sns.lineplot(x=itr,y=loss)
# Out:
# <Axes: >

# %%
#Q5
#2-6-1 EXOR relu bias

X2=np.array(([0,0],[0,1],[1,0],[1,1]), dtype=float)
y2=np.array(([0],[1],[1],[0]), dtype=float)

# Class definition
class NeuralNetwork5:
    def __init__(self, x,y):
        self.input = x #initializing x
        self.weights1= np.random.rand(self.input.shape[1],6) #initializing random weights
        self.weights2 = np.random.rand(6,1)#considering we have 6 nodes in the hidden layer
        self.bias1=np.random.rand(6,1)
        self.bias2=np.random.rand(1,1)
        self.y = y#initializing y
        self.output = np. zeros(y.shape)#initializing the output
        
    def feedforward(self):
        '''This will perform the forward propagation for the next 2 layers'''
        self.layer1 = sigmoid(np.dot(self.input, self.weights1))#calcuation of w_T*X+b for layer1
        self.layer2 = relu(np.dot(self.layer1, self.weights2))#calcuation of w_T*X+b for layer2
        return self.layer2
        
    def backprop(self):
        '''Back propagation of the final hidden layers to initial layers'''
        derv_weights2 = np.dot(self.layer1.T, 2*(self.y -self.output)*relu_derivative(self.output))#backpropagation of layer2
        derv_weights1 = np.dot(self.input.T, np.dot(2*(self.y -self.output)*sigmoid_derivative(self.output), self.weights2.T)*sigmoid_derivative(self.layer1))
        t_bias2=np.dot(self.bias1, 2*(self.y -self.output)*sigmoid_derivative(self.output))
        t_bias1= np.dot(self.input.T, np.dot(2*(self.y -self.output)*sigmoid_derivative(self.output), self.weights2.T)*sigmoid_derivative(self.bias1))
    
        self.weights1 += derv_weights1#updation of weight matrix of layer1
        self.weights2 += derv_weights2#updation of weight matrix of layer2
        bias1+=t_bias1
        bias2+=t_bias2

    def train(self, X, y):
        self.output = self.feedforward()#Forward Propagation
        self.backprop()#Backward Propagation

# %%
model=NeuralNetwork(X2,y2)
itr=list(range(100))
loss=[0]*100
for i in range(100):
    loss[i]=np.mean(np.square(y - model.feedforward()))
    if i % 100 ==0:#For each 100 epochs output will come 
        print ("for iteration # " + str(i) + "\n")
        print ("Input : \n" + str(X))
        print ("Actual Output: \n" + str(y))
        print ("Predicted Output: \n" + str(model.feedforward()))
        print ("Loss: \n" + str(np.mean(np.square(y - model.feedforward())))) # mean sum squared loss
        print ("\n")
  
    model.train(X, y)
# Out:
# for iteration # 0
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.70440382]
#  [0.76887728]
#  [0.73082453]
#  [0.78720974]]
# Loss:
# 0.31043926358926066

# %%
import seaborn as sns
sns.lineplot(x=itr,y=loss)
# Out:
# <Axes: >

# %%
#Q6
#2-6-1 EXOR relu relu

X2=np.array(([0,0],[0,1],[1,0],[1,1]), dtype=float)
y2=np.array(([0],[1],[1],[0]), dtype=float)

# Class definition
class NeuralNetwork6:
    def __init__(self, x,y):
        self.input = x #initializing x
        self.weights1= np.random.rand(self.input.shape[1],6) #initializing random weights
        self.weights2 = np.random.rand(6,1)#considering we have 6 nodes in the hidden layer
        self.bias1=np.random.rand(6,1)
        self.bias2=np.random.rand(1,1)
        self.y = y#initializing y
        self.output = np. zeros(y.shape)#initializing the output
        
    def feedforward(self):
        '''This will perform the forward propagation for the next 2 layers'''
        self.layer1 = relu(np.dot(self.input, self.weights1))#calcuation of w_T*X+b for layer1
        self.layer2 = relu(np.dot(self.layer1, self.weights2))#calcuation of w_T*X+b for layer2
        return self.layer2
        
    def backprop(self):
        '''Back propagation of the final hidden layers to initial layers'''
        derv_weights2 = np.dot(self.layer1.T, 2*(self.y -self.output)*relu_derivative(self.output))#backpropagation of layer2
        derv_weights1 = np.dot(self.input.T, np.dot(2*(self.y -self.output)*relu_derivative(self.output), self.weights2.T)*relu_derivative(self.layer1))
        t_bias2=np.dot(self.bias1, 2*(self.y -self.output)*relu_derivative(self.output))
        t_bias1= np.dot(self.input.T, np.dot(2*(self.y -self.output)*relu_derivative(self.output), self.weights2.T)*relu_derivative(self.bias1))
    
        self.weights1 += derv_weights1#updation of weight matrix of layer1
        self.weights2 += derv_weights2#updation of weight matrix of layer2
        bias1+=t_bias1
        bias2+=t_bias2

    def train(self, X, y):
        self.output = self.feedforward()#Forward Propagation
        self.backprop()#Backward Propagation_derivative(self.bias1))
    
        self.weights1 += derv_weights1#updation of weight matrix of layer1
        self.weights2 += derv_weights2#updation of weight matrix of layer2
        bias1+=t_bias1
        bias2+=t_bias2

    def train(self, X, y):
        self.output = self.feedforward()#Forward Propagation
        self.backprop()#Backward Propagation

# %%
model=NeuralNetwork(X2,y2)
itr=list(range(100))
loss=[0]*100
for i in range(100):
    loss[i]=np.mean(np.square(y - model.feedforward()))
    if i % 100 ==0:#For each 100 epochs output will come 
        print ("for iteration # " + str(i) + "\n")
        print ("Input : \n" + str(X))
        print ("Actual Output: \n" + str(y))
        print ("Predicted Output: \n" + str(model.feedforward()))
        print ("Loss: \n" + str(np.mean(np.square(y - model.feedforward())))) # mean sum squared loss
        print ("\n")
  
    model.train(X2, y2)
# Out:
# for iteration # 0
#
# Input :
# [[0. 0.]
#  [0. 1.]
#  [1. 0.]
#  [1. 1.]]
# Actual Output:
# [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Predicted Output:
# [[0.71391758]
#  [0.75315217]
#  [0.7473925 ]
#  [0.78116645]]
# Loss:
# 0.3111609342070415

# %%
import seaborn as sns
sns.lineplot(x=itr,y=loss)
# Out:
# <Axes: >
